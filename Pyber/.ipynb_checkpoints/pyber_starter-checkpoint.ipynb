# %% [markdown]
# #Observations

# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# File to Load (Remember to change these)
city_data_to_load = "data/city_data.csv"
ride_data_to_load = "data/ride_data.csv"

# Read the City and Ride Data
city_data = pd.read_csv(city_data_to_load)
ride_data = pd.read_csv(ride_data_to_load)

# Combine the data into a single dataset
combined_data = pd.merge(city_data, ride_data, on='city', how='outer')

# Display the data table for preview
combined_data.head()
# Out:
#           city  driver_count   type                 date   fare        ride_id
# 0  Richardfort            38  Urban  2018-02-24 08:40:38  13.93  5628545007794
# 1  Richardfort            38  Urban  2018-02-13 12:46:07  14.00   910050116494
# 2  Richardfort            38  Urban  2018-02-16 13:52:19  17.92   820639054416
# 3  Richardfort            38  Urban  2018-02-01 20:18:28  10.26  9554935945413
# 4  Richardfort            38  Urban  2018-04-17 02:26:37  23.00   720020655850

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
# Obtain the x and y coordinates for each of the three city types
group_city = combined_data.groupby(['city'])
avg_fare = group_city['fare'].mean()
ride_count = group_city['ride_id'].count()
driver_count = group_city['driver_count'].mean()
city_index = city_data.set_index('city')["type"]
city_index.head()

final_df = pd.DataFrame({"Average Fare":avg_fare,
                         "Total Rides":ride_count,
                         "Total Drivers":driver_count,
                         "City Type":city_index})
final_df.head()
# Out:
#                Average Fare  Total Rides  Total Drivers City Type
# Amandaburgh       24.641667           18             12     Urban
# Barajasview       25.332273           22             26     Urban
# Barronchester     36.422500           16             11  Suburban
# Bethanyland       32.956111           18             22  Suburban
# Bradshawfurt      40.064000           10              7     Rural

# %%
urban_city = final_df.loc[final_df["City Type"]=="Urban"]
suburban_city = final_df.loc[final_df["City Type"]=="Suburban"]
rural_city = final_df.loc[final_df["City Type"]=="Rural"]

# %%
# Build the scatter plots for each city types
plt.scatter(urban_city['Total Rides'], urban_city['Average Fare'], 
           s=urban_city['Total Drivers']*10, marker='o', color='LightCoral', 
           edgecolors='black', alpha=0.75, label='Urban')

plt.scatter(suburban_city['Total Rides'], suburban_city['Average Fare'], 
           s=suburban_city['Total Drivers']*10, marker='o', color='LightSKyBlue', 
           edgecolors='black', alpha=0.75, label='Suburban')

plt.scatter(rural_city['Total Rides'], rural_city['Average Fare'], 
           s=rural_city['Total Drivers']*10, marker='o', color='Gold', 
           edgecolors='black', alpha=0.75, label='Rural')

# Incorporate the other graph properties
plt.grid()
plt.title("Pyber Ride Sharing Data(2016)")
plt.xlabel("Total Number of Rides(Per City)")
plt.ylabel("Average Fare($)")

# Create a legend
plt.legend(title="City Types", loc = "upper right", markerscale=0.3)
lgnd = plt.legend()
lgnd.legendHandles[0]._sizes = [75]
lgnd.legendHandles[1]._sizes = [75]
lgnd.legendHandles[2]._sizes = [75]

# Incorporate a text label regarding circle size
plt.text(42,40,"Note:\n Circle size correlates with driver count per city.")

# Save Figure
plt.savefig("./Images/Pyber_Bubble_Plot.png")

# Show plot
plt.show()

# %% [markdown]
# ## Total Fares by City Type

# %%
# Calculate Type Percents
type_group = combined_data.groupby('type')
fare_sum = type_group['fare'].sum()

# Build Pie Chart
labels=['Rural', 'Suburban', 'Urban']
colors=['gold', 'lightskyblue', 'lightcoral']
explode=[0, 0, .1]

plt.pie(fare_sum, autopct="%.1f%%", labels=labels, colors=colors, 
        explode=explode, startangle=120, shadow=True)

plt.title("% of Total Fares by Market Type")
plt.axis("equal")

# Save Figure
plt.savefig("./Images/Pyber_Total_Fares_Pie.png")

plt.show()

# %% [markdown]
# ## Total Rides by City Type

# %%
# Calculate Ride Percents
ride_sum = type_group['ride_id'].count()

# Build Pie Chart
plt.pie(ride_sum, autopct="%.1f%%", labels=labels, colors=colors, 
        explode=explode, startangle=120, shadow=True)

plt.title("% of Total Rides by City Type")
plt.axis("equal")

# Save Figure
plt.savefig("./Images/Pyber_Total_Rides_Pie.png")

plt.show()

# %% [markdown]
# ## Total Drivers by City Type

# %%
# Calculate Driver Percents
group_d = city_data.groupby('type')
driver_sum = group_d['driver_count'].sum()


# Build Pie Charts
plt.pie(driver_sum, autopct="%.1f%%", labels=labels, colors=colors, 
        explode=explode, startangle=120, shadow=True)

plt.title("% of Total Drivers by City Type")
plt.axis("equal")

# Save Figure
plt.savefig("./Images/Pyber_Total_Drivers_Pie.png")

plt.show()
